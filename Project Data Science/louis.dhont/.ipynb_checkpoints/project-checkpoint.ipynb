# %% [markdown]
# # Data science project in Python
#
# Doormiddel van numpy, pandas, matplotlib & SciKit-learn
#
# Door Louis D'Hont - Elektronica-ICT - 2021

# %% [markdown]
# ## Project omschrijving
#
# Het doel van deze opdracht is om op basis van bepaalde features het type klanten dat over gaat tot een nieuwe boeking te bepalen met een algoritme. Deze features zijn gehaald uit de hieronder beschreven data beschikbaar gesteld door TrailFinders. Ze organiseren paardrijvakanties over de hele wereld en helpen daarnaast ook om de vlucht, accomodatie, huurwagen, verzekeringen en dergelijke te regelen.

# %%
#Importeren van gebruikte bibliotheken
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data analyse
#
# ### Inlezen van data en features bepalen
#
# Hieronder wordt de data die is aangeleverd behandeld.

# %%
klanten = pd.read_csv("../data/klanten.csv", sep=';') 
artikels = pd.read_csv("../data/artikels.csv", sep=';') 
bestellingen = pd.read_csv("../data/bestellingen.csv", sep=';') 
deelnemers = pd.read_csv("../data/deelnemers.csv", sep=';')

df_klanten = pd.DataFrame(klanten)
df_artikels = pd.DataFrame(artikels)
df_bestellingen = pd.DataFrame(bestellingen)
df_deelnemers = pd.DataFrame(deelnemers)

#delete row that is not useful
#to_drop = ['Straat + nr.', 'Telefoon']
#df.drop(to_drop, inplace = True, axis = 1)()

# %% [markdown]
# ### Klantenlijst
#
# Hieronder wordt de data uit de klantenlijst opgeruimd en aangepast.

# %%
#df_klanten['age'] = df_klanten['age'].astype('int64')
df_klanten.dtypes
# Out:
# Familienaam        object
# Voornaam           object
# Straat + nr.       object
# Telefoon           object
# Klantnummer        object
# Klantnummer CMS    object
# Email              object
# Creatie datum      object
# Geb. datum         object
# Locatie            object
# Postcode           object
# Land               object
# dtype: object

# %%
df_klanten['']

# %%
#check how many values are null
df_klanten.isnull().sum()
# Out:
# Familienaam           5
# Voornaam             65
# Straat + nr.         32
# Telefoon           1334
# Klantnummer           0
# Klantnummer CMS    1656
# Email                40
# Creatie datum      1473
# Geb. datum         2321
# Locatie              31
# Postcode             38
# Land                  2
# dtype: int64

# %%
# Replace numerical value with string
#df['gender'].replace(0, 'Female', inplace=True)
#df['gender'].replace(1, 'Male', inplace=True)
# Replace all values that equal a specific variable
#df = df.replace(valueToReplace =["current", "alsoCurrent"],value ="newvalue")

# %% [markdown]
# After review, there is 1 volcano event that doesn't have an age. The record that has a null value for the year, also has a null value for location, country, lat, long, etc. This record does not help analysis and will be dropped.
#
# To keep the default dataframe in tact, I've created a new dataframe and will clean up the data in this new dataframe. This is to ensure data is not skewed and can be compared after transformation.
#
# ### Data Quality
# - Create new dataframe
#  * Rename columns (change abbreviations to defined full words)
#  * Change data types for columns
#  * Handle null/NaN values
#
# There is only 1 record missing a year (and a number of key variables). This record doesn't help the analysis and will be dropped.
#
# Additionally, a number of the columns are either float or objects. After reviewing each column, the fields that are descriptive should be object instead of float.

# %%
# Create a new dataframe (keeping df_klanten integrity in tact). 
vdf = df_klanten

#vdf.sample(10)

# %%
df_klanten.sample(10)

# verwijder Straat + nr. kolom
# Verander de kolom namen
# wijzig het type voor de 'Creatie datum' en 'Geb. datum' kolommen
# gebruik klantnummer als index voor het dataframe
# gebruik het Klantnummer voor de NaN waarden in Klantnummer CMS
# verwijder de initialen (bv: JL of BS) en spaties uit de Postcode kolom
# Zet de Land kolom om naar 1 land (Be, BE, Belgium,..) = België
# vervang NaN in Geboortedatum met de geboortedatum uit de deelnemers lijst waar de familienaam en voornaam overeenkomen
#
# Out:
#            Familienaam          Voornaam      Straat + nr.          Telefoon  \
# 3354  bf89f80a487ce42f  34694cab861bc5c6  b07fe19c5ed2900b  699bcff73af4324d
# 707   2fbce8799c8694a0  cb863496b066dde2  c8dcc85319802093  45c5263859017cfc
# 744   2a01e38fb6b33f71  f836873ed9e19a4e  f067b242fcbca841               NaN
# 3591  8717da881c71803e  c8aad0434684dfd6  11801a2781e91f6c  cd274f21321f134e
# 2614  c3e6b04eee898799  9e613d3d0a66730c  b3154f468b1ec820  4d41885c2c07d79b
# 2113  f108d43aa32dbd75  f160020b0a7c3c41  df64b5b56134b56b               NaN
# 3367  1f12c3a58f9de4fc  be9b409aefc6f5b6  a79c448f165fa6fb               NaN
# 1463  99b61aa2d4d2e389  9a5d9b7453a8ba70  beb0be4eae649260  15e6e62f8d793741
# 145   d629a987e31b0aec  e56c0326e8052f2d  3d4ccd4bddf30438  58a24d65581955dc
# 3088  b4eb1c39edb7e990  cff05efbf075a827  c01b1060fdca52bb  97f7ed3d2b0e0f96
#
#            Klantnummer   Klantnummer CMS             Email Creatie datum  \
# 3354  fb229c9ae2b7fce8               NaN  e67b9c13e11bfd0b    09.02.2019
# 707   9551b5e23cc7bbe6               NaN  6ed763c6b70a6343    30.07.2013
# 744   86757bda286ef32f  6726b32f113fc54c  6ccf84bd03d61661           NaN
# 3591  6acd2b2b43df6352  f7e80f1b4ca80c85  f746ebaed342cf30    26.12.2015
# 2614  781836942bf7aa5f  1427d8d1ab6cc290  65902455b8536221    05.02.2018
# 2113  70c55c19c5e2dd8b  2f2b76f52ac32717  a1d6ca1df78797f1           NaN
# 3367  ecc36a12406ba615               NaN  5e9cb40d0e7a4f78    07.06.2013
# 1463  f41fdd12d5508f53  f27cd171019c7a6a  e135842f8e54ea91           NaN
# 145   f38b6d7042ea8f5a               NaN  5e7ec7f52fac02d0    10.10.2013
# 3088  7ce1ecaff4c0c368               NaN  f4dc74b36390325b    09.01.2012
#
#       Geb. datum               Locatie Postcode        Land
# 3354  20.08.1961                Dongen   5103BL          nl
# 707          NaN              ZAVENTEM     1930     Belgium
# 744          NaN               Utrecht   3581cl  Nederlands
# 3591         NaN  Heilig Landstichting  6564 AT  0633799726
# 2614         NaN               Vleuten  3452 CR   Nederland
# 2113         NaN           Nieuwenrode     1880      Belgie
# 3367  08.04.1988             Hilversum  1211 NM     Belgium
# 1463         NaN               belfeld  5951 JC   nederland
# 145   23.02.1951                IZEGEM     8870     Belgium
# 3088  25.02.1975                Cothen  3945 BR   Nederland

# %%
#df_klanten.shape

# %%
df_artikels.sample(10)

# verwijder ArticlePoNummer kolom
# zet Boekingsdatum en Vertrekdatum om naar juiste type datetime
# vervang Volledige naam klant door klantennummer uit klantenlijst door te zoeken met dossier nummer
# vervang DossierStatus 'Ok' met 1 of 0
# maak dataframe (labels) met alle bestemmingen
# Out:
#        Dos. nr. DossierStatus        Boekingsdatum         Vertrekdatum  \
# 5940       1093            Ok  24.07.2013 21:24:13  02.08.2013 00:00:00
# 12496  20190291            Ok  15.05.2019 22:10:54  22.05.2019 00:00:00
# 12636  20190413            Ok  02.08.2019 16:51:22  06.10.2019 00:00:00
# 8308       2196            Ok  19.01.2016 00:00:00  09.10.2016 00:00:00
# 12920  20190550            Ok  11.12.2019 11:13:51  25.09.2020 00:00:00
# 7428       1782            Ok  16.03.2015 08:35:45  05.07.2015 00:00:00
# 7530       1830            Ok  08.04.2015 00:00:00  12.09.2015 00:00:00
# 86          817            Ok  03.03.2013 00:00:00  05.07.2013 00:00:00
# 11760      3871            Ok  17.07.2018 00:00:00  16.08.2018 00:00:00
# 3424        150            Ok  04.08.2011 10:48:13  07.10.2001 00:00:00
#
#       Volledige naam klant                                         Bestemming  \
# 5940      87e1254aff8b713f                                    Estartit Spanje
# 12496     eef5791b1b677dc4                         Minitrip in Zuid-Frankrijk
# 12636     b0bc4c0ddfcf8a96                        Beach and Meadows trektocht
# 8308      0bd34b7eac71c5e0  Te paard door de vier valleien van het Gredos-...
# 12920     57c454ac0aa404c3                                          Nederland
# 7428      51b068d078f48ff4                         Wekerom, Veluwe, Nederland
# 7530      4cee6605af5db834                                 Dalmatie trektocht
# 86        0831d0ecbda287bb          Paardrijden met IJslanders in de Ardennen
# 11760     dc2411af110ff0a9                                           Mongolie
# 3424      80bd69298b33cba5                                    Ardennen Belgie
#
#        ArticlePoNummer       Artikelcode  \
# 5940               NaN  5603505c44a65622
# 12496              NaN  fae29d340036a451
# 12636              NaN  6fda33407485b945
# 8308               NaN  cab3a360a079380d
# 12920              NaN  ec40042ba9accb21
# 7428               NaN  88c28cd844903eb8
# 7530               NaN               NaN
# 86                 NaN  2c3990e373fce35f
# 11760              NaN  87c30f637cd21cd0
# 3424               NaN  4e06bdc84db28683
#
#                                             Omschrijving Artikelprijs  \
# 5940                              Dynamigo Estartit Plus        29,00
# 12496                                   Verzameltransfer         0,00
# 12636                                 Toeristenbelasting         7,00
# 8308               Trektocht Vier Valleien van de Gredos     1.150,00
# 12920  Ramsjo-special NOK 13.100,- eerste en laatste ...     1.287,00
# 7428                                   Korting NG Junior         0,00
# 7530                              Vlucht Brussel - Split       410,46
# 86                   Paardrijweekend IJslanders Ardennen       620,00
# 11760                         Aeroflot vluchtreservering       702,46
# 3424   Weekend Ardennen ontdekken, 2 pk gezamenlijk s...       520,00
#
#       Totaal dossier
# 5940          794,00
# 12496         506,30
# 12636       2.907,00
# 8308        1.150,00
# 12920         685,37
# 7428          570,00
# 7530        2.325,46
# 86            760,00
# 11760       3.981,46
# 3424          554,20

# %%
#df_artikels.shape

# %%
dfBestellingen.sample(10)

# Dos.jaar = 2021.0 - moet date worden en niet float zijn
# kolomnaam D.vertrek en Datum terug hernoemen
# status -1 en 0 omzetten naar 1 of 0
# verwijder laatste rij - is het totaal van alles opgeteld
# verwijder de regio kolom (veel NaN)
# verwijder de gefactureerd kolom of zet om naar 1 of 0 - type int64
# verwijder de Pakket Code kolom
# verwijder Touroperator kolom (Waarschijnlijk niet relevant)
# Zet Datum creatie, D. vertrek en Datum terug om naar datetime type
# Zet bestemming en 'Land klant' om naar 1 land (Be, BE, Belgium,..) = België
# zet Totaalprijs en Openstaand dossier om naar het type int64
#
# Out:
#       Status  Dos. jaar  Dos. nr.             Email       Klantnummer  \
# 3883     0.0     2020.0  20200178  911f574852c24223  845e2be869bec98e
# 31       0.0     2011.0        45  47d5ced2f4e37c7c  836ed014bdf68e6e
# 3291     0.0     2018.0      4171  83139054b6a11223  5069f81b40d0d92b
# 2632     0.0     2017.0      3210  9f6c02bc9591beaa  01db6ffe4f6bd8d4
# 1536     0.0     2015.0      1948  0d8adea50f0b7bb2  b39b7e400b46d662
# 2897     0.0     2018.0      3558  5169b4821788fff1  f80c0c468f1aa0b0
# 129     -1.0     2011.0       166  6b4bfa846590dddf  86f033218b01dc22
# 3571     0.0     2019.0  20190355  9a598f6e6544197f  124a6fbc21c6b514
# 2050     0.0     2016.0      2543  1a346cd9f5d2aa94  462ebf0beb9b4519
# 2038     0.0     2016.0      2530  fe590b92546d179b  5933f2b8e8beff60
#
#        Klantnummer CMS        Datum creatie  D. vertrek Datum terug  \
# 3883               NaN  04.06.2020 10:06:19  17.07.2020  19.07.2020
# 31                 NaN  19.05.2011 12:08:02  15.07.2011  17.07.2011
# 3291  36e47b015fbf9f0a  18.12.2018 19:55:10  19.05.2019  25.05.2019
# 2632  d503e5dcdec91197  12.08.2017 00:00:00  23.08.2017  27.08.2017
# 1536  a1d04193ab96b666  12.06.2015 00:00:00  13.07.2015  17.07.2015
# 2897               NaN  01.03.2018 10:52:10  30.09.2018  07.10.2018
# 129                NaN  19.08.2011 12:22:57  11.09.2011  18.09.2011
# 3571  7ada21e52d2fc8a2  24.06.2019 08:11:08  04.08.2019  10.08.2019
# 2050  31fc2d0337ff95b9  30.06.2016 00:00:00  26.09.2016  02.10.2016
# 2038  2a7d852524ac7d0f  20.06.2016 00:00:00  24.07.2016  30.07.2016
#
#      Totaalprijs Betalingen dossier Openstaand dossier      Touroperator  \
# 3883         600                600                  0  59fd5bafb3a477af
# 31        290,38             290,38                  0  80ea2db9dbc6f9fd
# 3291   3301,6398            3301,64            -0,0002  84eade0373defc7f
# 2632         435                435                  0  d5b44b89737b542f
# 1536         606                606                  0  27ef3947de4c44d2
# 2897        1586               1586                  0  7db3edcc64762299
# 129      1901,85            1901,85                  0  7526875b2e15e594
# 3571        1115               1115                  0  4481a08dd57dc705
# 2050      1545,3             1545,3                  0  f0f28f3a76ecde1d
# 2038        1060               1060                  0  68ede1259463edeb
#
#        Land klant                                         Bestemming  Regio  \
# 3883           nl                                             België    NaN
# 31    Netherlands                                             Twente    NaN
# 3291           be                                          Schotland    NaN
# 2632    Nederland  Paardrijden en gastronomisch genieten in Zuid-...    NaN
# 1536       België               Paardrijden op het strand in Zeeland    NaN
# 2897    Nederland                                         Montenegro    NaN
# 129     Nederland                                     Galway Ierland    NaN
# 3571           nl                                          Frankrijk    NaN
# 2050    Nederland                               Beach and Bush Rides    NaN
# 2038    Nederland  Transsylvanië - Trektocht eeuwen terug in de tijd    NaN
#
#             Reistype  # pass. Pakket Code Gefactureerd
# 3883             NaN      2.0   BEWETLWKP         True
# 31               NaN      1.0         NaN         True
# 3291  Ruitervakantie      2.0    GBSCETRP        False
# 2632             NaN      1.0         NaN         True
# 1536             NaN      2.0         NaN         True
# 2897             NaN      1.0         NaN         True
# 129              NaN      1.0         NaN         True
# 3571  Ruitervakantie      1.0    FRCHAGVP         True
# 2050             NaN      1.0         NaN         True
# 2038             NaN      1.0         NaN         True

# %%
#df_bestellingen.shape

# %%
df_deelnemers.sample(10)

# verwijder GSM kolom
# vewijder email kolom (veel NaN) - ook prive data
# zet Postcode om naar het type int64
# zet Vertrekdatum om naar datetime
# verwijder cijfers uit Stad bv: Brussel 15
#
# Out:
#        Dossier Vertrekdatum       Familienaam          Voornaam  \
# 3799      2397   18.05.2016  ba564cdced717785  7f34aaff6575be84
# 1547       983   28.06.2013  13e3b28b7c2e8177  3ab19e38d4515950
# 1303       829   28.06.2013  31c0b699dc243c04  c4b164876985eccc
# 6767  20190310   20.07.2019  18be5c1ec4af9cb6  947a131bc3cdfdf0
# 4277      2702   25.03.2017  065a5ad87a48ad59  89633fd3420af8bf
# 1872      1198   26.07.2014  7e82411ca3760d63  43a243417550dfb1
# 7345  20200277   31.07.2020  51d599c297c5a262  4c4eb9449e2e7186
# 6466  20190104   27.07.2019  3a0a6f773d6da573  9ad124aabe38821d
# 4741      2973   23.06.2017  400b37f3df0d5865  4eef05d035288259
# 4944      3101   02.07.2017  4d4f0e3025560653  496181b08c1d0f31
# 2514      1627   23.10.2014  3f40db29b1aa86ca  2c4d68a4475f76af
# 5570      3544   29.07.2018  38b033c51453c6dd  501b8a4516623972
# 1688      1088   16.08.2013  c9ed71fb26b412d4  1987313de87d7a3b
# 2549      1647   18.07.2015  6e2e5e08d5a88367  6e2e5e08d5a88367
# 2697      1723   21.09.2015  ced4617171f6c187  6331921d6f5bb2a3
# 2936      1858   21.06.2015  0456026fc73c5211  98f803764d963896
# 2221      1418   26.07.2014  2a8c345e32c323ef  9194a11ccd90c3fe
# 1816      1167   09.08.2014  ceaffaeffc17cfec  a87fa5d78958327b
# 3244      2069   15.10.2015  8fb925d8a5117bd7  7ba20f63acc06325
# 2844      1808   01.05.2015  e18086e1df6732f9  6f58f0b9d2f5a357
#
#                                              Bestemming Geboortedatum  \
# 3799                                                NaN    22.07.1972
# 1547                  Western paardrijden in de Algarve    12.07.1979
# 1303                                     Jura Frankrijk    08.09.1958
# 6767                                            Ierland    10.10.1956
# 4277  Een onvergetelijke reis doorheen het winters l...    14.10.1994
# 1872      Lesbos -een echt paardeneiland in Griekenland    22.08.1966
# 7345                                          Nederland    19.05.1997
# 6466                                          Frankrijk    04.01.1954
# 4741                                   Belgie, ardennen    12.03.1990
# 4944           Paardrijden in de Elzas, door de Vogezen    04.09.1959
# 2514                                             Zweden    07.09.1983
# 5570                                          Noorwegen    06.03.1993
# 1688                                  Moliets Frankrijk    25.03.1998
# 2549                  Beginnersweek te paard in Beieren    17.07.1969
# 2697                                          Hongarije    16.10.1963
# 2936  Te paard door de vier valleien van het Gredos-...    31.08.1967
# 2221                          De Balkan trail Bulgarije    31.01.1973
# 1816                                Servia & Montenegro    08.06.1960
# 3244                                    Ardennen belgie    27.03.1958
# 2844                      Western rijden in de Ardennen           NaN
#
#                  Email               GSM      Straat + nr. Postcode       Stad
# 3799               NaN               NaN  603cf213567d1d53  1073 CW  Amsterdam
# 1547               NaN               NaN               NaN      NaN        NaN
# 1303               NaN               NaN  603cf213567d1d53  1073 CW  Amsterdam
# 6767               NaN               NaN               NaN      NaN        NaN
# 4277               NaN               NaN               NaN      NaN        NaN
# 1872               NaN               NaN               NaN      NaN        NaN
# 7345               NaN               NaN               NaN      NaN        NaN
# 6466               NaN               NaN               NaN      NaN        NaN
# 4741               NaN               NaN               NaN      NaN        NaN
# 4944               NaN               NaN               NaN      NaN        NaN
# 2514  cc7c06eb000efd73  3553fe872e61ecc6  17e9151879127f20  3581 XX    Utrecht
# 5570  7ff1fa164ef3d5bf               NaN               NaN      NaN        NaN
# 1688               NaN               NaN  871038c9b1006874     3570      ALKEN
# 2549               NaN               NaN               NaN      NaN        NaN
# 2697               NaN               NaN  5614ffe6bc5133f2     9120    VRASENE
# 2936               NaN               NaN               NaN      NaN        NaN
# 2221               NaN               NaN               NaN      NaN        NaN
# 1816               NaN               NaN               NaN      NaN        NaN
# 3244  5169b4821788fff1               NaN  f828e1afcba2bdef  2624 NX      delft
# 2844               NaN               NaN               NaN      NaN        NaN

# %%
#df['Klantnummer'].is_unique

#make specific row as index
#df.set_index('Klantnummer', inplace=True)
#df

# %%
# aantal waarden die null zijn in de klantenlijst
#df.isnull().sum()
# Out:
# Familienaam           5
# Voornaam             65
# Klantnummer           0
# Klantnummer CMS    1656
# Email                40
# Creatie datum      1473
# Geb. datum         2321
# Locatie              31
# Postcode             38
# Land                  2
# dtype: int64

# %%
df.columns
# Out:
# Index(['Familienaam', 'Voornaam', 'Straat + nr.', 'Telefoon',
#        'Klantnummer CMS', 'Email', 'Creatie datum', 'Geb. datum', 'Locatie',
#        'Postcode', 'Land'],
#       dtype='object')

# %%
#land lijst opruimen (België, belgium, BE) wijzigen naar 1 formaat
#achternaam van deelnemers kunnen worden gelinked met het klantennummer van een bestelling
#Geboortedatum in kantenlijst kan ge

# %%
df.dtypes
# Out:
# Familienaam        object
# Voornaam           object
# Straat + nr.       object
# Telefoon           object
# Klantnummer CMS    object
# Email              object
# Creatie datum      object
# Geb. datum         object
# Locatie            object
# Postcode           object
# Land               object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3677 entries, 0 to 3676
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Familienaam      3672 non-null   object
#  1   Voornaam         3612 non-null   object
#  2   Straat + nr.     3645 non-null   object
#  3   Telefoon         2343 non-null   object
#  4   Klantnummer      3677 non-null   object
#  5   Klantnummer CMS  2021 non-null   object
#  6   Email            3637 non-null   object
#  7   Creatie datum    2204 non-null   object
#  8   Geb. datum       1356 non-null   object
#  9   Locatie          3646 non-null   object
#  10  Postcode         3639 non-null   object
#  11  Land             3675 non-null   object
# dtypes: object(12)
# memory usage: 344.8+ KB

# %%
#values count
df.Email.value_counts(dropna=False)
# Out:
# NaN                 40
# 1849215198727a0e     3
# f53d3a92477e4351     3
# 378c4185c3deca7e     3
# 796c9ac12c162681     3
#                     ..
# af3509085b43bd51     1
# f9fb57ba6b04e378     1
# f97519ab8da32fe6     1
# 1c6c43f6f34d4020     1
# bb43c4e59617e9c8     1
# Name: Email, Length: 3575, dtype: int64

# %%
df_klanten.describe()
# Out:
#              Familienaam          Voornaam      Straat + nr.  \
# count               3672              3612              3645
# unique              2998              1610              3568
# top     bf89f80a487ce42f  1f952ba892536b36  424c2e99b6f2dc7f
# freq                  16                33                 4
#
#                 Telefoon       Klantnummer   Klantnummer CMS  \
# count               2343              3677              2021
# unique              2298              3677              2020
# top     a056db0fd0bfa0b5  8c7cca2fb7a135ea  1fe831773451dd74
# freq                   4                 1                 2
#
#                    Email Creatie datum  Geb. datum    Locatie Postcode  \
# count               3637          2204        1356       3646     3639
# unique              3574           968        1286       1583     2710
# top     f53d3a92477e4351    23.03.2017  04.04.1982  Amsterdam     2600
# freq                   3            12           4        181       20
#
#              Land
# count        3675
# unique         82
# top     Nederland
# freq         1472

# %%
#df.boxplot(column='Email', by='Telefoon', rot=90)

# %% [markdown]
# # Features bepalen
#
# Enkele interessante features die in de data te vinden zijn:
#
# * Feature1

# %% [markdown]
# ### importeren
#
# Voordat
